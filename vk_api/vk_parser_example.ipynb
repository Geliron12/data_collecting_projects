# %%
from vk_parse import VkParser

# %%
parser = VkParser(USER_TOKEN='Your user token')

# %%
parser.parse_vk_weekly(query='your query')

# %%
parser = VkParser('')
parser.parse_vk_weekly('СПбГУ')
parser.plot_stats()
# Out:
# {'Число постов': 1588, 'Суммарное число лайков': 34524, 'Суммарное число комментариев': 3128, 'Суммарное число репостов': 6817, 'Суммарное число просмотров': 2106634, 'Суммарное число пользователей и групп': 1217}

# %%
parser = VkParser('')
parser.parse_vk_weekly('МГУ')
parser.plot_stats()
# Out:
# {'Число постов': 3785, 'Суммарное число лайков': 80342, 'Суммарное число комментариев': 5012, 'Суммарное число репостов': 14111, 'Суммарное число просмотров': 6168370, 'Суммарное число пользователей и групп': 2928}
